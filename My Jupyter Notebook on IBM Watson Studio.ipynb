# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kritsada Klaimak**
#
# My current occupation is software engineer.

# %% [markdown]
# *I am interested in data science because ...*

# %% [markdown]
# ### The next code is supposed to

# %%
1+1
# Out:
# 2

# %% [markdown]
# Here is the list:
#
# - list 1
# - list 2
# - list 3
#
# ```json
# {
#     "name": "Kritsada",
#     "title": "My Jupyter Notebook on IBM Watson Studio"
# }
# ```
#
# | Name | Type | Description |
# | --- | --- | --- |
# | sample 1 | String (64) | This is sample 1 field |
# | sample 2 | String (18) | This is sample 2 field |
#
# > This is a sample of writing blockquote...
